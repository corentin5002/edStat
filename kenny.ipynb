# %% [markdown]
# Vous êtes Data Scientist dans une start-up de la EdTech, nommée academy, qui propose des contenus de formation en ligne pour un public de niveau lycée et université.
#
# Mark, votre manager, vous a convié à une réunion pour vous présenter le projet d’expansion à l’international de l’entreprise. Il vous confie une première mission d’analyse exploratoire, pour déterminer si les données sur l’éducation de la banque mondiale permettent d’informer le projet d’expansion.
#
# Voici les différentes questions que Mark aimerait explorer, que vous avez notées durant la réunion :
#
# Quels sont les pays avec un fort potentiel de clients pour nos services ?
# Pour chacun de ces pays, quelle sera l’évolution de ce potentiel de clients ?
# Dans quels pays l'entreprise doit-elle opérer en priorité ?
# Votre mission
# Mark vous a donc demandé de réaliser une analyse pré-exploratoire de ce jeu de données. Il vous a transmis cet email à la suite de la réunion :
#
# Hello,
#
# Les données de la Banque mondiale sont disponibles à l’adresse suivante :
#
# https://datacatalog.worldbank.org/dataset/education-statistics
#
# Ou en téléchargement direct à ce lien.
#
# Je te laisse regarder la page d'accueil qui décrit le jeu de données. En résumé, l’organisme “EdStats All Indicator Query” de la Banque mondiale répertorie 4000 indicateurs internationaux décrivant l’accès à l’éducation, l’obtention de diplômes et des informations relatives aux professeurs, aux dépenses liées à l’éducation... Tu trouveras plus d'info sur ce site :
#
# http://datatopics.worldbank.org/education/
#
# Pour la pré-analyse, pourrais-tu :
#
# Valider la qualité de ce jeu de données (comporte-t-il beaucoup de données manquantes, dupliquées ?)
#
# Décrire les informations contenues dans le jeu de données (nombre de colonnes ? nombre de lignes ?)
#
# Sélectionner les informations qui semblent pertinentes pour répondre à la problématique (quelles sont les colonnes contenant des informations qui peuvent être utiles pour répondre à la problématique de l’entreprise ?)
#
# Déterminer des ordres de grandeurs des indicateurs statistiques classiques pour les différentes zones géographiques et pays du monde (moyenne/médiane/écart-type par pays et par continent ou bloc géographique)
#
# Ton travail va nous permettre de déterminer si ce jeu de données peut informer les décisions d'ouverture vers de nouveaux pays. On va partager ton analyse avec le board, alors merci de soigner la présentation et de l'illustrer avec des graphiques pertinents et lisibles !

# %%
# import de tout les dependances
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
footnote = pd.read_csv('./CSV/EdStatsFootNote.csv')
country = pd.read_csv('./CSV/EdStatsCountry.csv')
series = pd.read_csv('./CSV/EdStatsSeries.csv')
data = pd.read_csv('./CSV/EdStatsData.csv')
cseries = pd.read_csv('./CSV/EdStatsCountry-Series.csv')

# %%
footnote.head()
 # afficher moi le datafram mais que la ou le countrycode == ABW
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
footnote.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4'], dtype='object')

# %%
country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %%
series.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %%
series.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
cseries.head()
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW        SP.POP.TOTL
# 1         ABW        SP.POP.GROW
# 2         AFG        SP.POP.GROW
# 3         AFG  NY.GDP.PCAP.PP.CD
# 4         AFG        SP.POP.TOTL
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data sources: United Nations World Population ...         NaN
# 2  Data sources: United Nations World Population ...         NaN
# 3                 Estimates are based on regression.         NaN
# 4  Data sources : United Nations World Population...         NaN

# %%
cseries.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')

# %%
data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
# dans la table supprimer toute les colonnes apres 2024 cad 2025 à Unnamed: 69
data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %% [markdown]
# # Mon Apporche

# %% [markdown]
# ###  Comment j'ai procedé ...

# %%
# compter le nombre des pays dans country "Short Name"

country['Short Name'].count()
# Out:
# 241

# %%
# le classifier par continent "Region"
country['Region'].unique()
# Out:
# array(['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
#        'Europe & Central Asia', nan, 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
#afficher chaque pays par region "Region"
country.groupby('Region')['Short Name'].unique()
# Out:
# Region
# East Asia & Pacific           [American Samoa, Australia, Brunei, China, Fij...
# Europe & Central Asia         [Albania, Andorra, Armenia, Austria, Azerbaija...
# Latin America & Caribbean     [Aruba, Argentina, Antigua and Barbuda, The Ba...
# Middle East & North Africa    [United Arab Emirates, Bahrain, Djibouti, Alge...
# North America                                  [Bermuda, Canada, United States]
# South Asia                    [Afghanistan, Bangladesh, Bhutan, India, Sri L...
# Sub-Saharan Africa            [Angola, Burundi, Benin, Burkina Faso, Botswan...
# Name: Short Name, dtype: object

# %%
# nombre des pays par region
country.groupby('Region')['Short Name'].count()
# Out:
# Region
# East Asia & Pacific           36
# Europe & Central Asia         57
# Latin America & Caribbean     41
# Middle East & North Africa    21
# North America                  3
# South Asia                     8
# Sub-Saharan Africa            48
# Name: Short Name, dtype: int64

# %%
#commment voir le nombre de de fois qu'une region domine dans la table data
data['Country Name'].value_counts()
# Out:
# Country Name
# Arab World               3665
# Portugal                 3665
# Micronesia, Fed. Sts.    3665
# Moldova                  3665
# Monaco                   3665
#                          ...
# Equatorial Guinea        3665
# Eritrea                  3665
# Estonia                  3665
# Ethiopia                 3665
# Zimbabwe                 3665
# Name: count, Length: 242, dtype: int64

# %%
#j'aimerai merge country et data pour avoir un seul dataframe en gardant les colone de data et en ajoutant les colones de country je veux un inner 

merge1 = pd.merge(data, country, left_on='Country Code', right_on='Country Code',how='inner')

# %%
merge1["Region"]
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                  ...
# 883260    Sub-Saharan Africa
# 883261    Sub-Saharan Africa
# 883262    Sub-Saharan Africa
# 883263    Sub-Saharan Africa
# 883264    Sub-Saharan Africa
# Name: Region, Length: 883265, dtype: object

# %%
merge1.groupby('Region')['Short Name'].count()
# Out:
# Region
# East Asia & Pacific           131940
# Europe & Central Asia         208905
# Latin America & Caribbean     150265
# Middle East & North Africa     76965
# North America                  10995
# South Asia                     29320
# Sub-Saharan Africa            175920
# Name: Short Name, dtype: int64

# %%
merge1.head()   # ceci est le merge de la table data et country
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN       NaN  ...
# ...

# %%
merge1['2020'].notnull().sum()
# Out:
# 51436

# %%
merge1['2020'].isnull().sum()
# Out:
# 831829

# %%
merge1.shape
# Out:
# (883265, 101)

# %%
merge2 = pd.merge(merge1, series, left_on='Indicator Code', right_on='Series Code', how='inner')

# %%
merge2.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                     Indicator Name_x  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN       NaN  ...
# ...

# %%
merge2.shape
# Out:
# (870492, 122)

# %%
merge3 = pd.merge(merge2, cseries, left_on=['Country Code'], right_on=['CountryCode'], how='inner')

# %%
merge3.shape
# Out:
# (2214156, 126)

# %%
merge3.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                     Indicator Name_x Indicator Code  1970  \
# 0  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 1  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 2  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 3  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 4  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
#
#    1971  1972  1973     1974  1975  ...  Development relevance  \
# 0   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# 1   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# 2   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# 3   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# ...

# %%
count_duplicates_merge3 = merge3.duplicated().sum()
print("Nombre de doublons dans merge3 :", count_duplicates_merge3)
# Out:
# Nombre de doublons dans merge3 : 0

# %%
merge3.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                     Indicator Name_x Indicator Code  1970  \
# 0  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 1  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 2  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 3  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 4  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
#
#    1971  1972  1973     1974  1975  ...  Development relevance  \
# 0   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# 1   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# 2   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# 3   NaN   NaN   NaN  7.05911   NaN  ...                    NaN
# ...

# %%
merge3.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name_x', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975',
#        ...
#        'Development relevance', 'Related source links', 'Other web links',
#        'Related indicators', 'License Type', 'Unnamed: 20', 'CountryCode',
#        'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'],
#       dtype='object', length=126)

# %%
merge3.shape
# Out:
# (2214156, 126)

# %%
mergefiltre= merge3[merge3['Country Code'] == merge3['CountryCode']]
mergefiltre.shape
# Out:
# (2214156, 126)

# %%
unique_country_codes_merge3 = merge3['Country Code'].unique()
unique_country_codes_CountryCode = merge3['CountryCode'].unique()

print("Nombre de valeurs uniques dans 'Country Code' :", len(unique_country_codes_merge3))
print("Nombre de valeurs uniques dans 'CountryCode' :", len(unique_country_codes_CountryCode))
# Out:
# Nombre de valeurs uniques dans 'Country Code' : 211
# Nombre de valeurs uniques dans 'CountryCode' : 211

# %%
merge_filtre = merge3.drop_duplicates()

# %%
# Out:
# 0                  South Asia
# 1                  South Asia
# 2                  South Asia
# 3                  South Asia
# 4                  South Asia
#                   ...
# 2214151    Sub-Saharan Africa
# 2214152    Sub-Saharan Africa
# 2214153    Sub-Saharan Africa
# 2214154    Sub-Saharan Africa
# 2214155    Sub-Saharan Africa
# Name: Region, Length: 2214156, dtype: object

# %% [markdown]
# ## Création de 7 DataFrames, chacun contenant les données spécifiques aux pays de leur région respective

# %%
df_east_asia_pacific = merge3[merge3['Region'] == 'East Asia & Pacific']

# %%
df_europe_central_asia = merge3[merge3['Region'] == 'Europe & Central Asia']

# %%
df_latin_america_caribbean = merge3[merge3['Region'] == 'Latin America & Caribbean']

# %%
df_middle_east_north_africa = merge3[merge3['Region'] == 'Middle East & North Africa']

# %%
df_north_america = merge3[merge3['Region'] == 'North America']

# %%
df_south_asia = merge3[merge3['Region'] == 'South Asia']

# %%
df_sub_saharan_africa = merge3[merge3['Region'] == 'Sub-Saharan Africa']
